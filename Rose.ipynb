# %%
import numpy as np, pandas as pd

# %%
# !pip install pyecharts

# %%
from pyecharts.charts import Pie
from pyecharts import options as opts

# %%
df= pd.read_csv('polarbear-rose.csv')

# %%
c = df['District'].values.tolist()
d = df['Case Rate'].values.tolist()
#create the color_series for the rosechart
color_series = ['#802200','#B33000','#FF4500','#FAA327','#9ECB3C',
 '#6DBC49','#37B44E','#14ADCF','#209AC9','#1E91CA',
 '#2C6BA0','#2B55A1','#2D3D8E','#44388E','#6A368B',
 '#D02C2A','#D44C2D','#F57A34','#FA8F2F','#D99D21']
rosechart = Pie(init_opts=opts.InitOpts(width='3000px', height='900px'))
# set the color
rosechart.set_colors(color_series)
# add the data to the rosechart
rosechart.add("", [list(z) for z in zip(c, d)],
        radius=["35%", "140%"],  # 20% inside radius，95% ourside radius
        center=["20%", "80%"],   # center of the chart
        rosetype="area")# set the global options for the chart
rosechart.set_global_opts(legend_opts=opts.LegendOpts(is_show=True),
                     toolbox_opts=opts.ToolboxOpts())# set the series options
rosechart.set_series_opts(label_opts=opts.LabelOpts(is_show=False, font_size=12, formatter="{b}:{c}%"),)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)

# %%
chart=rosechart.render_notebook()
chart
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0c11fed123e34da3894740debdf7e121" style="width:3000px; height:900px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0c11fed123e34da3894740debdf7e121 = echarts.init(
#                     document.getElementById('0c11fed123e34da3894740debdf7e121'), 'white', {renderer: 'canvas'});
#                 var option_0c11fed123e34da3894740debdf7e121 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#802200",
#         "#B33000",
#         "#FF4500",
#         "#FAA327",
#         "#9ECB3C",
#         "#6DBC49",
#         "#37B44E",
#         "#14ADCF",
#         "#209AC9",
#         "#1E91CA",
#         "#2C6BA0",
#         "#2B55A1",
#         "#2D3D8E",
#         "#44388E",
#         "#6A368B",
#         "#D02C2A",
#         "#D44C2D",
#         "#F57A34",
#         "#FA8F2F",
#         "#D99D21"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "Dhaka",
#                     "value": 0.00821519
#                 },
#                 {
#                     "name": "Chattogram",
#                     "value": 0.005982876999999999
#                 },
#                 {
#                     "name": "Gazipur",
#                     "value": 0.00287339
#                 },
#                 {
#                     "name": "Narayanganj",
#                     "value": 0.0019315110000000001
#                 },
#                 {
#                     "name": "Faridpur",
#                     "value": 0.0011323639999999999
#                 },
#                 {
#                     "name": "Cox's Bazar",
#                     "value": 0.000845919
#                 },
#                 {
#                     "name": "Jashore",
#                     "value": 0.000757596
#                 },
#                 {
#                     "name": "Narsingdi",
#                     "value": 0.000678927
#                 },
#                 {
#                     "name": "Madaripur",
#                     "value": 0.0006559789999999999
#                 },
#                 {
#                     "name": "Barishal",
#                     "value": 0.000622701
#                 },
#                 {
#                     "name": "Naogaon",
#                     "value": 0.000586138
#                 },
#                 {
#                     "name": "Mymensing",
#                     "value": 0.000579235
#                 },
#                 {
#                     "name": "Noakhali",
#                     "value": 0.000577361
#                 },
#                 {
#                     "name": "Lakshmipur",
#                     "value": 0.000571404
#                 },
#                 {
#                     "name": "Bogura",
#                     "value": 0.000548248
#                 },
#                 {
#                     "name": "Sylhet",
#                     "value": 0.0005067380000000001
#                 },
#                 {
#                     "name": "Joypurhat",
#                     "value": 0.000503256
#                 },
#                 {
#                     "name": "Bandarban",
#                     "value": 0.000499103
#                 },
#                 {
#                     "name": "Khulna",
#                     "value": 0.00047219
#                 },
#                 {
#                     "name": "Kishoreganj",
#                     "value": 0.000469646
#                 },
#                 {
#                     "name": "Shariatpur",
#                     "value": 0.000395069
#                 },
#                 {
#                     "name": "Chandpur",
#                     "value": 0.000338718
#                 },
#                 {
#                     "name": "Rajbari",
#                     "value": 0.000338229
#                 },
#                 {
#                     "name": "Munshiganj",
#                     "value": 0.00033649900000000003
#                 },
#                 {
#                     "name": "Sunamganj",
#                     "value": 0.000327042
#                 },
#                 {
#                     "name": "Feni",
#                     "value": 0.000299953
#                 },
#                 {
#                     "name": "Dinajpur",
#                     "value": 0.000275852
#                 },
#                 {
#                     "name": "Kushtia",
#                     "value": 0.00026676099999999996
#                 },
#                 {
#                     "name": "Moulvibazar",
#                     "value": 0.00026524
#                 },
#                 {
#                     "name": "Rangpur",
#                     "value": 0.00025869900000000004
#                 },
#                 {
#                     "name": "Manikganj",
#                     "value": 0.00025474
#                 },
#                 {
#                     "name": "Gopalganj",
#                     "value": 0.000252197
#                 },
#                 {
#                     "name": "Barguna",
#                     "value": 0.000245733
#                 },
#                 {
#                     "name": "Habiganj",
#                     "value": 0.000238495
#                 },
#                 {
#                     "name": "Brahmmanbaria",
#                     "value": 0.000223369
#                 },
#                 {
#                     "name": "Netrokona",
#                     "value": 0.00021074
#                 },
#                 {
#                     "name": "Rajshahi",
#                     "value": 0.000194054
#                 },
#                 {
#                     "name": "Cumilla",
#                     "value": 0.000191681
#                 },
#                 {
#                     "name": "Jamalpur",
#                     "value": 0.00017664900000000002
#                 },
#                 {
#                     "name": "Jhenaidah",
#                     "value": 0.00017052299999999998
#                 },
#                 {
#                     "name": "Rangamati",
#                     "value": 0.000163235
#                 },
#                 {
#                     "name": "Sherpur",
#                     "value": 0.000162884
#                 },
#                 {
#                     "name": "Nilphamari",
#                     "value": 0.00016201600000000002
#                 },
#                 {
#                     "name": "Pabna",
#                     "value": 0.000156823
#                 },
#                 {
#                     "name": "Bhola",
#                     "value": 0.000151017
#                 },
#                 {
#                     "name": "Pirojpur",
#                     "value": 0.000140137
#                 },
#                 {
#                     "name": "Tangail",
#                     "value": 0.00013722799999999998
#                 },
#                 {
#                     "name": "Thakurgaon",
#                     "value": 0.000126782
#                 },
#                 {
#                     "name": "Patuakhali",
#                     "value": 0.00012516600000000001
#                 },
#                 {
#                     "name": "Panchagarh",
#                     "value": 0.00011737399999999999
#                 },
#                 {
#                     "name": "Bagerhat",
#                     "value": 0.000116213
#                 },
#                 {
#                     "name": "Sirajganj",
#                     "value": 0.000107914
#                 },
#                 {
#                     "name": "Jhalakhati",
#                     "value": 9.956030000000001e-05
#                 },
#                 {
#                     "name": "Natore",
#                     "value": 8.59823e-05
#                 },
#                 {
#                     "name": "Meherpur",
#                     "value": 8.45291e-05
#                 },
#                 {
